# %% [markdown]
# **Variáveis do tipo inteiro**

# %%
idade = 22

# %%
idade2 = (idade + 2)

# %%
idade2
# Out:
# 24

# %%
media = idade2/8

# %%
media
# Out:
# 3.0

# %% [markdown]
# **Variáveis do tipo float**

# %%
altura = 1.69

# %% [markdown]
# **Variáveis do tipo Lista**

# %%
lista = [1, 2, 3, 4, 5]

# %%
lista[2]
# Out:
# 3

# %%
lista[1] = 8

# %%
lista
# Out:
# [1, 8, 3, 4, 5]

# %%
lista[-1]
# Out:
# 5

# %%
lista[3:5]
# Out:
# [4, 5]

# %%
lista[1] = 2

# %%
lista[1:3]  ##slicing
# Out:
# [2, 3]

# %%
lista[:4]
# Out:
# [1, 2, 3, 4]

# %%
lista[2:]
# Out:
# [3, 4, 5]

# %% [markdown]
# **Variáveis do tipo String**

# %%
nome = 'Mailton'

# %%
sobrenome = "Farias"

# %%
nome[3]
# Out:
# 'l'

# %%
nome[:3]
# Out:
# 'Mai'

# %%
sobrenome[:-1]
# Out:
# 'Faria'

# %%
idade3 = '15'

# %%
idade3 * 2
# Out:
# '1515'

# %%
idade3 + '4'   ##concatena duas strins
# Out:
# '154'

# %%
nome + sobrenome
# Out:
# 'MailtonFarias'

# %%
nome + ' ' + sobrenome
# Out:
# 'Mailton Farias'

# %%
nome.upper() #deixa tudo com letra maiúscula
# Out:
# 'MAILTON'

# %%
nome.lower() #deixa tudo com letra minúscula
# Out:
# 'mailton'

# %% [markdown]
# **DIcionários**

# %%
d = {1:'um',2:'dois',3:'três'}

# %%
d[1]
# Out:
# 'um'

# %%
d
# Out:
# {1: 'um', 2: 'dois', 3: 'três'}

# %%
d[2], d[3]
# Out:
# ('dois', 'três')

# %%
dicionario = {3: 'Mailton', 4:'Giovana'}

# %%
dicionario[3]
# Out:
# 'Mailton'

# %%
dicionario.keys()
# Out:
# dict_keys([3, 4])

# %%
dicionario.values()
# Out:
# dict_values(['Mailton', 'Giovana'])

# %% [markdown]
# **Variáveis do tipo Bool**

# %%
verdadeiro = True
Falso = False

# %%
Hoje_e_feriado = verdadeiro

# %%
Hoje_e_feriado
# Out:
# True

# %%
type(idade)
# Out:
# int

# %%
type(altura)
# Out:
# float

# %%
type(dicionario)
# Out:
# dict

# %%
print('Meus dados:',nome,idade,altura,sobrenome)
# Out:
# Meus dados: Mailton 22 1.69 Farias

# %%
print(lista)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# **Operadores relacionais** # São comparações

# %%
1 == 1
# Out:
# True

# %%
1 == 3
# Out:
# False

# %%
1 != 1
# Out:
# False

# %%
idade > idade2
# Out:
# False

# %%
idade > altura
# Out:
# True

# %%
type(dicionario) == type(d)
# Out:
# True

# %%
type(idade) != type(nome)
# Out:
# True

# %% [markdown]
# **Operadores de Lógica**  #not and or

# %%
not(type(dicionario) == type(d))
# Out:
# False

# %%
(1 == 1) and (2 == 2)
# Out:
# True

# %%
(1 > 4) and (3 != 4)
# Out:
# False

# %%
(1 > 4) or (3 != 4)
# Out:
# True

# %% [markdown]
# **Desvio Condicional**

# %%
if (3 == 3):
  print('Sim')
else:
  print('Nao')
# Out:
# Sim

# %%
if (2 == 3): print('Sim, 2 é igual a 3')
elif(2 == 2): print('Sim, 2 é igual a 2')
else: print('Os numeros não são iguais')
# Out:
# Sim, 2 é igual a 2

# %% [markdown]
# **Função Input**

# %%
nome = input('Qual seu nome? ')
# Out:
# Qual seu nome? Mailton

# %%
numero = input ('Digite sua idade: ')
# Out:
# Digite sua idade: 22

# %%
numero = float(input ('Digite um numero: '))
# Out:
# Digite um numero: 6

# %%
numero + 8
# Out:
# 14.0

# %% [markdown]
# **Operação Casting**

# %%
list('Mailton')
# Out:
# ['M', 'a', 'i', 'l', 't', 'o', 'n']

# %%
int(5.3704)
# Out:
# 5

# %%
bool([])
# Out:
# False

# %%
bool(8759924855859.34)
# Out:
# True

# %%
str([lista])
# Out:
# '[[1, 2, 3, 4, 5]]'

# %%
3 in lista
# Out:
# True

# %% [markdown]
# **EXERCÍCIO**
# 1. Faça um programa que peça um valor e mostre se o valor é positivo  ou negativo

# %%
valor = int(input('Digite um valor: '))
# Out:
# Digite um valor: 8

# %%
if (valor > 0): 
  print(valor, 'é positivo')
elif(valor < 0):
  print(valor, 'é negativo')
else: 
  print(valor, 'é neutro')
# Out:
# 8 é positivo
